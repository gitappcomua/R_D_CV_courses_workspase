# %% [markdown]
# # HOMEWORK 13
#
# In this homework you are going to build your first classifier for the CIFAR-10 dataset. This dataset contains 10 different classes and you can learn more about it [here](https://www.cs.toronto.edu/~kriz/cifar.html). This homework consists of the following tasks:
# * Dataset inspection
# * Building the network
# * Training
# * Evaluation
#
# At the end, as usual, there will be a couple of questions for you to answer :-)

# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras.layers import Conv2D, Dense, Flatten, Input, MaxPooling2D
from tensorflow.keras import Model
from time import time

from matplotlib import pyplot as plt
plt.rcParams['figure.figsize'] = [15, 10]

# Set the seeds for reproducibility
from numpy.random import seed
from tensorflow.random import set_seed
seed_value = 1234578790
seed(seed_value)
set_seed(seed_value)

# %% [markdown]
# ### Step 0: Dataset Inspection
#
# Load the dataset and make a quick inspection.

# %%
# Load the dataset
(x_train, y_train), (x_test, y_test) = tf.keras.datasets.cifar10.load_data()
# Mapping from class ID to class name

classes = {0:'plane', 1:'car', 2:'bird', 3:'cat', 4:'deer',
           5:'dog', 6:'frog', 7:'horse', 8:'ship', 9:'truck'}

# Dataset params
num_classes = len(classes)
size = x_train.shape[1]
#size

# Visualize random samples (as a plot with 3x6 samples)
for ii in range(18):    
    plt.subplot(3,6,ii+1)
    # Pick a random sample
    idx = np.random.randint(0, len(y_train))
    # Show the image and the label
    plt.imshow(x_train[idx, ...])
    plt.title(classes[int(y_train[idx])])

# %% [markdown]
# Compute the class histogram (you can visualize it if you want). Is the dataset balanced?
#
# Hint: You might find [Counter](https://docs.python.org/3/library/collections.html#collections.Counter) tool useful. In any case, it's up to you how you compute the histogram.

# %%
# Compute the class histogram
from collections import Counter
hist = Counter(y_train[:,0])

plt.bar(hist.keys(), hist.values()), plt.grid(True)
plt.xlabel('Traffic Sign ID'), plt.ylabel('Counts')
# Out:
# (Text(0.5, 0, 'Traffic Sign ID'), Text(0, 0.5, 'Counts'))

# %% [markdown]
# ### Step 1: Data Preparation
#
# In this step, you'll need to prepare the data for training, i.e., you will have to normalize it and encode the labels as one-hot vectors.

# %%
# Normalization
x_train = x_train/255
x_test = x_test/255

# One-hot encoding
y_train = tf.keras.utils.to_categorical(y_train, num_classes)
y_test = tf.keras.utils.to_categorical(y_test, num_classes)

print('Train set:   ', len(y_train), 'samples')
print('Test set:    ', len(y_test), 'samples')
print('Sample dims: ', x_train.shape)
# Out:
# Train set:    50000 samples
# Test set:     10000 samples
# Sample dims:  (50000, 32, 32, 3)

# %% [markdown]
# ### Step 2: Building the Classifier
#
# Build the CNN for CIFAR10 classification. For starters, you can use the same network we used in the lesson for the MNIST problem.

# %%
# Build the classifier
inputs = Input(shape=(size, size, 3))

net = Conv2D(16, kernel_size=(3, 3), activation="relu")(inputs)
net = MaxPooling2D(pool_size=(2, 2))(net)
net = Conv2D(32, kernel_size=(3, 3), activation="relu")(net)
net = MaxPooling2D(pool_size=(2, 2))(net)
net = Flatten()(net)
outputs = Dense(num_classes, activation="softmax")(net)

model = Model(inputs, outputs)

# Show the model
model.summary()
# Out:
# Model: "functional_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 32, 32, 3)]       0
# _________________________________________________________________
# conv2d (Conv2D)              (None, 30, 30, 16)        448
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 15, 15, 16)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 13, 13, 32)        4640
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 6, 6, 32)          0
# _________________________________________________________________
# flatten (Flatten)            (None, 1152)              0
# _________________________________________________________________
# dense (Dense)                (None, 10)                11530
# =================================================================
# Total params: 16,618
# Trainable params: 16,618
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### Step 3: Training
#
# Compile the model and train it.

# %%
epochs = 50
batch_size = 128

# Compile the model
model.compile(loss="categorical_crossentropy", optimizer="adam", metrics=["accuracy"])

# Train the model
history = model.fit(x_train, y_train, batch_size=batch_size, epochs=epochs, validation_split=0.1)
# Out:
# Epoch 1/50
# 352/352 [==============================] - 22s 63ms/step - loss: 1.7576 - accuracy: 0.3748 - val_loss: 1.5719 - val_accuracy: 0.4464
# Epoch 2/50
# 352/352 [==============================] - 21s 60ms/step - loss: 1.4355 - accuracy: 0.4962 - val_loss: 1.3594 - val_accuracy: 0.5186
# Epoch 3/50
# 352/352 [==============================] - 19s 54ms/step - loss: 1.3380 - accuracy: 0.5308 - val_loss: 1.3048 - val_accuracy: 0.5468
# Epoch 4/50
# 352/352 [==============================] - 19s 55ms/step - loss: 1.2719 - accuracy: 0.5537 - val_loss: 1.2355 - val_accuracy: 0.5712
# Epoch 5/50
# 352/352 [==============================] - 19s 53ms/step - loss: 1.2265 - accuracy: 0.5742 - val_loss: 1.2095 - val_accuracy: 0.5836
# Epoch 6/50
# 352/352 [==============================] - 19s 54ms/step - loss: 1.1869 - accuracy: 0.5862 - val_loss: 1.1588 - val_accuracy: 0.6036
# Epoch 7/50
# 352/352 [==============================] - 18s 52ms/step - loss: 1.1555 - accuracy: 0.5991 - val_loss: 1.1553 - val_accuracy: 0.5976
# Epoch 8/50
# 352/352 [==============================] - 20s 55ms/step - loss: 1.1240 - accuracy: 0.6102 - val_loss: 1.1449 - val_accuracy: 0.6020
# Epoch 9/50
# 352/352 [==============================] - 19s 54ms/step - loss: 1.0987 - accuracy: 0.6218 - val_loss: 1.1268 - val_accuracy: 0.6118
# Epoch 10/50
# 352/352 [==============================] - 18s 51ms/step - loss: 1.0800 - accuracy: 0.6264 - val_loss: 1.0933 - val_accuracy: 0.6246
# Epoch 11/50
# 352/352 [==============================] - 18s 52ms/step - loss: 1.0569 - accuracy: 0.6330 - val_loss: 1.0672 - val_accuracy: 0.6354
# Epoch 12/50
# 352/352 [==============================] - 18s 51ms/step - loss: 1.0397 - accuracy: 0.6423 - val_loss: 1.0549 - val_accuracy: 0.6398
# Epoch 13/50
# 352/352 [==============================] - 18s 52ms/step - loss: 1.0208 - accuracy: 0.6482 - val_loss: 1.0573 - val_accuracy: 0.6394
# Epoch 14/50
# 352/352 [==============================] - 19s 55ms/step - loss: 1.0056 - accuracy: 0.6538 - val_loss: 1.0603 - val_accuracy: 0.6408
# Epoch 15/50
# 352/352 [==============================] - 20s 58ms/step - loss: 0.9910 - accuracy: 0.6588 - val_loss: 1.0258 - val_accuracy: 0.6456
# Epoch 16/50
# 352/352 [==============================] - 19s 54ms/step - loss: 0.9758 - accuracy: 0.6657 - val_loss: 1.0216 - val_accuracy: 0.6474
# Epoch 17/50
# 352/352 [==============================] - 19s 54ms/step - loss: 0.9639 - accuracy: 0.6685 - val_loss: 1.0299 - val_accuracy: 0.6462
# Epoch 18/50
# 352/352 [==============================] - 20s 56ms/step - loss: 0.9529 - accuracy: 0.6736 - val_loss: 1.0050 - val_accuracy: 0.6590
# Epoch 19/50
# 352/352 [==============================] - 19s 53ms/step - loss: 0.9420 - accuracy: 0.6764 - val_loss: 0.9923 - val_accuracy: 0.6650
# Epoch 20/50
# 352/352 [==============================] - 21s 59ms/step - loss: 0.9295 - accuracy: 0.6806 - val_loss: 1.0026 - val_accuracy: 0.6606
# Epoch 21/50
# 352/352 [==============================] - 22s 61ms/step - loss: 0.9238 - accuracy: 0.6816 - val_loss: 1.0009 - val_accuracy: 0.6598
# Epoch 22/50
# 352/352 [==============================] - 21s 60ms/step - loss: 0.9169 - accuracy: 0.6853 - val_loss: 0.9996 - val_accuracy: 0.6564
# Epoch 23/50
# 352/352 [==============================] - 19s 55ms/step - loss: 0.9014 - accuracy: 0.6911 - val_loss: 0.9718 - val_accuracy: 0.6696
# Epoch 24/50
# 352/352 [==============================] - 21s 58ms/step - loss: 0.8957 - accuracy: 0.6917 - val_loss: 1.0052 - val_accuracy: 0.6548
# Epoch 25/50
# 352/352 [==============================] - 20s 57ms/step - loss: 0.8902 - accuracy: 0.6945 - val_loss: 0.9901 - val_accuracy: 0.6556
# Epoch 26/50
# 352/352 [==============================] - 20s 58ms/step - loss: 0.8852 - accuracy: 0.6977 - val_loss: 0.9886 - val_accuracy: 0.6614
# Epoch 27/50
# 352/352 [==============================] - 24s 67ms/step - loss: 0.8807 - accuracy: 0.6976 - val_loss: 0.9815 - val_accuracy: 0.6644
# Epoch 28/50
# 352/352 [==============================] - 24s 69ms/step - loss: 0.8703 - accuracy: 0.7023 - val_loss: 0.9761 - val_accuracy: 0.6664
# Epoch 29/50
# 352/352 [==============================] - 22s 64ms/step - loss: 0.8641 - accuracy: 0.7028 - val_loss: 0.9696 - val_accuracy: 0.6688
# Epoch 30/50
# 352/352 [==============================] - 23s 66ms/step - loss: 0.8594 - accuracy: 0.7038 - val_loss: 0.9559 - val_accuracy: 0.6718
# Epoch 31/50
# 352/352 [==============================] - 22s 62ms/step - loss: 0.8527 - accuracy: 0.7079 - val_loss: 0.9578 - val_accuracy: 0.6728
# Epoch 32/50
# 352/352 [==============================] - 24s 68ms/step - loss: 0.8493 - accuracy: 0.7092 - val_loss: 0.9611 - val_accuracy: 0.6732
# Epoch 33/50
# 352/352 [==============================] - 23s 64ms/step - loss: 0.8443 - accuracy: 0.7101 - val_loss: 0.9663 - val_accuracy: 0.6734
# Epoch 34/50
# 352/352 [==============================] - 23s 64ms/step - loss: 0.8417 - accuracy: 0.7096 - val_loss: 0.9558 - val_accuracy: 0.6804
# Epoch 35/50
# 352/352 [==============================] - 22s 62ms/step - loss: 0.8386 - accuracy: 0.7112 - val_loss: 0.9687 - val_accuracy: 0.6734
# Epoch 36/50
# 352/352 [==============================] - 20s 56ms/step - loss: 0.8328 - accuracy: 0.7139 - val_loss: 0.9796 - val_accuracy: 0.6628
# Epoch 37/50
# 352/352 [==============================] - 21s 60ms/step - loss: 0.8266 - accuracy: 0.7164 - val_loss: 0.9696 - val_accuracy: 0.6724
# Epoch 38/50
# 352/352 [==============================] - 21s 60ms/step - loss: 0.8209 - accuracy: 0.7178 - val_loss: 0.9761 - val_accuracy: 0.6710
# Epoch 39/50
# 352/352 [==============================] - 21s 59ms/step - loss: 0.8176 - accuracy: 0.7180 - val_loss: 0.9580 - val_accuracy: 0.6778
# Epoch 40/50
# 352/352 [==============================] - 20s 58ms/step - loss: 0.8167 - accuracy: 0.7191 - val_loss: 0.9566 - val_accuracy: 0.6736
# Epoch 41/50
# 352/352 [==============================] - 23s 65ms/step - loss: 0.8092 - accuracy: 0.7223 - val_loss: 0.9642 - val_accuracy: 0.6756
# Epoch 42/50
# 352/352 [==============================] - 23s 67ms/step - loss: 0.8051 - accuracy: 0.7236 - val_loss: 0.9565 - val_accuracy: 0.6802
# Epoch 43/50
# 352/352 [==============================] - 24s 68ms/step - loss: 0.8072 - accuracy: 0.7225 - val_loss: 0.9789 - val_accuracy: 0.6714
# Epoch 44/50
# 352/352 [==============================] - 24s 68ms/step - loss: 0.8026 - accuracy: 0.7244 - val_loss: 0.9755 - val_accuracy: 0.6708
# Epoch 45/50
# 352/352 [==============================] - 23s 64ms/step - loss: 0.7981 - accuracy: 0.7246 - val_loss: 0.9528 - val_accuracy: 0.6770
# Epoch 46/50
# 352/352 [==============================] - 21s 61ms/step - loss: 0.7961 - accuracy: 0.7252 - val_loss: 0.9573 - val_accuracy: 0.6796
# Epoch 47/50
# 352/352 [==============================] - 19s 55ms/step - loss: 0.7890 - accuracy: 0.7298 - val_loss: 0.9536 - val_accuracy: 0.6782
# Epoch 48/50
# 352/352 [==============================] - 22s 63ms/step - loss: 0.7874 - accuracy: 0.7284 - val_loss: 0.9606 - val_accuracy: 0.6806
# Epoch 49/50
# 352/352 [==============================] - 26s 74ms/step - loss: 0.7836 - accuracy: 0.7300 - val_loss: 0.9544 - val_accuracy: 0.6818
# Epoch 50/50
# 352/352 [==============================] - 23s 65ms/step - loss: 0.7836 - accuracy: 0.7299 - val_loss: 0.9561 - val_accuracy: 0.6840

# %%
# Show training history (this cell is complete, nothing to implement here :-) )
h = history.history
epochs = range(len(h['loss']))

plt.subplot(121), plt.plot(epochs, h['loss'], '.-', epochs, h['val_loss'], '.-')
plt.grid(True), plt.xlabel('epochs'), plt.ylabel('loss')
plt.legend(['Train', 'Validation'])
plt.subplot(122), plt.plot(epochs, h['accuracy'], '.-',
                           epochs, h['val_accuracy'], '.-')
plt.grid(True), plt.xlabel('epochs'), plt.ylabel('Accuracy')
plt.legend(['Train', 'Validation'])

print('Train Acc     ', h['accuracy'][-1])
print('Validation Acc', h['val_accuracy'][-1])
# Out:
# Train Acc      0.7299333214759827
# Validation Acc 0.6840000152587891

# %% [markdown]
# ### Step 4: Evaluation
#
# In this step, you have to calculate the accuracies and visualize some random samples. For the evaluation, you are going to use the test split from the dataset.

# %%
# Compute the labels and the predictions as sparse values
y_true = np.argmax(y_test, axis=1)
y_pred = model.predict(x_test)

print('True', y_true[0:5])
print('Pred', np.argmax(y_pred[0:5, :], axis=1))
print('Pred', y_pred[0:5, :])
print(y_pred.shape)
# Out:
# True [3 8 8 0 6]
# Pred [3 1 1 0 6]
# Pred [[3.21293774e-04 7.64501092e-05 2.50720000e-03 9.66834843e-01
#   4.09639790e-04 1.54144475e-02 1.93948078e-03 7.27018123e-05
#   1.11849532e-02 1.23902096e-03]
#  [3.85288112e-02 5.94275713e-01 9.27279234e-06 1.18408678e-07
#   2.73654473e-06 8.69370620e-09 2.05135873e-08 3.10964310e-07
#   3.27608585e-01 3.95744592e-02]
#  [1.07008636e-01 6.64683700e-01 2.73318146e-04 1.19718444e-03
#   1.06965576e-03 1.38579795e-04 6.29274655e-06 1.09692467e-02
#   1.73241153e-01 4.14121971e-02]
#  [6.38707697e-01 1.45004466e-01 9.09773074e-03 3.95729323e-04
#   9.45148524e-03 8.30399586e-06 3.34191631e-04 1.47189037e-03
#   1.85144112e-01 1.03844712e-02]
#  [2.71940894e-06 7.34845351e-04 1.27248829e-02 2.59627700e-02
#   1.08545750e-01 3.14750941e-03 8.48805428e-01 1.01903997e-05
#   5.05286916e-05 1.54047229e-05]]
# (10000, 10)

# %%
# Compute and print the accuracy for each class
for class_id, class_name in classes.items():
    #print(class_id)
    acc = np.sum((np.argmax(y_pred, axis=1)==np.argmax(y_test, axis=1)) & (np.argmax(y_test, axis=1)==class_id))/np.sum(np.argmax(y_test, axis=1)==class_id)
    print(class_name, acc)
# Out:
# plane 0.682
# car 0.839
# bird 0.524
# cat 0.508
# deer 0.615
# dog 0.535
# frog 0.747
# horse 0.688
# ship 0.809
# truck 0.761

# %%
# Print the overall stats
ev = model.evaluate(x_test, y_test)
print('Test loss  ', ev[0])
print('Test metric', ev[1])
# Out:
# 313/313 [==============================] - 2s 6ms/step - loss: 0.9698 - accuracy: 0.6708
# Test loss   0.969826877117157
# Test metric 0.670799970626831

# %%
# Show random samples
for ii in range(15):
    # Pick a random sample
    idx = np.random.randint(0, len(y_test))
    # Show the results
    plt.subplot(3,5,ii+1), plt.imshow(x_test[idx, ...])
    plt.title('True: ' + str(classes[y_true[idx]]) + ' | Pred: ' + str(classes[np.argmax(y_pred, axis=1)[idx]]))

# %% [markdown]
# ### Questions
# * What is the overall accuracy of the classifier?
# * What modifications would you do in order to improve the classification accuracy?
# * Make **one** modification (that you think can help) and train the classifier again. Does the accuracy improve?
