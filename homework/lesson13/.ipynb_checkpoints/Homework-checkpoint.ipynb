# %% [markdown]
# # HOMEWORK 13
#
# In this homework you are going to build your first classifier for the CIFAR-10 dataset. This dataset contains 10 different classes and you can learn more about it [here](https://www.cs.toronto.edu/~kriz/cifar.html). This homework consists of the following tasks:
# * Dataset inspection
# * Building the network
# * Training
# * Evaluation
#
# At the end, as usual, there will be a couple of questions for you to answer :-)

# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras.layers import Conv2D, Dense, Flatten, Input, MaxPooling2D
from tensorflow.keras import Model
from time import time

from matplotlib import pyplot as plt
plt.rcParams['figure.figsize'] = [15, 10]

# Set the seeds for reproducibility
from numpy.random import seed
from tensorflow.random import set_seed
seed_value = 1234578790
seed(seed_value)
set_seed(seed_value)

# %% [markdown]
# ### Step 0: Dataset Inspection
#
# Load the dataset and make a quick inspection.

# %%
# Load the dataset
(x_train, y_train), (x_test, y_test) = tf.keras.datasets.cifar10.load_data()
# Mapping from class ID to class name

classes = {0:'plane', 1:'car', 2:'bird', 3:'cat', 4:'deer',
           5:'dog', 6:'frog', 7:'horse', 8:'ship', 9:'truck'}

# Dataset params
num_classes = len(classes)
size = x_train.shape[1]
#size

# Visualize random samples (as a plot with 3x6 samples)
for ii in range(18):    
    plt.subplot(3,6,ii+1)
    # Pick a random sample
    idx = np.random.randint(0, len(y_train))
    # Show the image and the label
    plt.imshow(x_train[idx, ...])
    plt.title(classes[int(y_train[idx])])

# %% [markdown]
# Compute the class histogram (you can visualize it if you want). Is the dataset balanced?
#
# Hint: You might find [Counter](https://docs.python.org/3/library/collections.html#collections.Counter) tool useful. In any case, it's up to you how you compute the histogram.

# %%
# Compute the class histogram
from collections import Counter
hist = Counter(y_train[:,0])

plt.bar(hist.keys(), hist.values()), plt.grid(True)
plt.xlabel('Traffic Sign ID'), plt.ylabel('Counts')
# Out:
# (Text(0.5, 0, 'Traffic Sign ID'), Text(0, 0.5, 'Counts'))

# %% [markdown]
# ### Step 1: Data Preparation
#
# In this step, you'll need to prepare the data for training, i.e., you will have to normalize it and encode the labels as one-hot vectors.

# %%
# Normalization
x_train = x_train/255
x_test = x_test/255

# One-hot encoding
y_train = tf.keras.utils.to_categorical(y_train, num_classes)
y_test = tf.keras.utils.to_categorical(y_test, num_classes)

print('Train set:   ', len(y_train), 'samples')
print('Test set:    ', len(y_test), 'samples')
print('Sample dims: ', x_train.shape)
# Out:
# Train set:    50000 samples
# Test set:     10000 samples
# Sample dims:  (50000, 32, 32, 3)

# %% [markdown]
# ### Step 2: Building the Classifier
#
# Build the CNN for CIFAR10 classification. For starters, you can use the same network we used in the lesson for the MNIST problem.

# %%
# Build the classifier
inputs = Input(shape=(size, size, 3))

net = Conv2D(16, kernel_size=(3, 3), activation="relu")(inputs)
net = MaxPooling2D(pool_size=(2, 2))(net)
net = Conv2D(32, kernel_size=(3, 3), activation="relu")(net)
net = MaxPooling2D(pool_size=(2, 2))(net)
net = Flatten()(net)
outputs = Dense(num_classes, activation="softmax")(net)

model = Model(inputs, outputs)

# Show the model
model.summary()
# Out:
# Model: "functional_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 32, 32, 3)]       0
# _________________________________________________________________
# conv2d (Conv2D)              (None, 30, 30, 16)        448
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 15, 15, 16)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 13, 13, 32)        4640
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 6, 6, 32)          0
# _________________________________________________________________
# flatten (Flatten)            (None, 1152)              0
# _________________________________________________________________
# dense (Dense)                (None, 10)                11530
# =================================================================
# Total params: 16,618
# Trainable params: 16,618
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### Step 3: Training
#
# Compile the model and train it.

# %%
epochs = 25
batch_size = 128

# Compile the model
model.compile(loss="categorical_crossentropy", optimizer="adam", metrics=["accuracy"])

# Train the model
history = model.fit(x_train, y_train, batch_size=batch_size, epochs=epochs, validation_split=0.1)
# Out:
# Epoch 1/25
# 352/352 [==============================] - 22s 61ms/step - loss: 1.7576 - accuracy: 0.3748 - val_loss: 1.5719 - val_accuracy: 0.4464
# Epoch 2/25
# 352/352 [==============================] - 20s 56ms/step - loss: 1.4355 - accuracy: 0.4962 - val_loss: 1.3594 - val_accuracy: 0.5186
# Epoch 3/25
# 352/352 [==============================] - 21s 59ms/step - loss: 1.3380 - accuracy: 0.5308 - val_loss: 1.3048 - val_accuracy: 0.5468
# Epoch 4/25
# 352/352 [==============================] - 20s 58ms/step - loss: 1.2719 - accuracy: 0.5537 - val_loss: 1.2355 - val_accuracy: 0.5712
# Epoch 5/25
# 352/352 [==============================] - 19s 53ms/step - loss: 1.2265 - accuracy: 0.5742 - val_loss: 1.2095 - val_accuracy: 0.5836
# Epoch 6/25
# 352/352 [==============================] - 19s 54ms/step - loss: 1.1869 - accuracy: 0.5862 - val_loss: 1.1588 - val_accuracy: 0.6036
# Epoch 7/25
# 352/352 [==============================] - 19s 54ms/step - loss: 1.1555 - accuracy: 0.5991 - val_loss: 1.1553 - val_accuracy: 0.5976
# Epoch 8/25
# 352/352 [==============================] - 19s 54ms/step - loss: 1.1240 - accuracy: 0.6102 - val_loss: 1.1449 - val_accuracy: 0.6020
# Epoch 9/25
# 352/352 [==============================] - 21s 61ms/step - loss: 1.0987 - accuracy: 0.6218 - val_loss: 1.1268 - val_accuracy: 0.6118
# Epoch 10/25
# 352/352 [==============================] - 21s 59ms/step - loss: 1.0800 - accuracy: 0.6264 - val_loss: 1.0933 - val_accuracy: 0.6246
# Epoch 11/25
# 352/352 [==============================] - 20s 56ms/step - loss: 1.0569 - accuracy: 0.6330 - val_loss: 1.0672 - val_accuracy: 0.6354
# Epoch 12/25
# 352/352 [==============================] - 20s 56ms/step - loss: 1.0397 - accuracy: 0.6423 - val_loss: 1.0549 - val_accuracy: 0.6398
# Epoch 13/25
# 352/352 [==============================] - 21s 60ms/step - loss: 1.0208 - accuracy: 0.6482 - val_loss: 1.0573 - val_accuracy: 0.6394
# Epoch 14/25
# 352/352 [==============================] - 20s 57ms/step - loss: 1.0056 - accuracy: 0.6538 - val_loss: 1.0603 - val_accuracy: 0.6408
# Epoch 15/25
# 352/352 [==============================] - 20s 56ms/step - loss: 0.9910 - accuracy: 0.6588 - val_loss: 1.0258 - val_accuracy: 0.6456
# Epoch 16/25
# 352/352 [==============================] - 24s 68ms/step - loss: 0.9758 - accuracy: 0.6657 - val_loss: 1.0216 - val_accuracy: 0.6474
# Epoch 17/25
# 352/352 [==============================] - 19s 53ms/step - loss: 0.9639 - accuracy: 0.6685 - val_loss: 1.0299 - val_accuracy: 0.6462
# Epoch 18/25
# 352/352 [==============================] - 17s 49ms/step - loss: 0.9529 - accuracy: 0.6736 - val_loss: 1.0050 - val_accuracy: 0.6590
# Epoch 19/25
# 352/352 [==============================] - 17s 49ms/step - loss: 0.9420 - accuracy: 0.6764 - val_loss: 0.9923 - val_accuracy: 0.6650
# Epoch 20/25
# 352/352 [==============================] - 17s 48ms/step - loss: 0.9295 - accuracy: 0.6806 - val_loss: 1.0026 - val_accuracy: 0.6606
# Epoch 21/25
# 352/352 [==============================] - 18s 50ms/step - loss: 0.9238 - accuracy: 0.6816 - val_loss: 1.0009 - val_accuracy: 0.6598
# Epoch 22/25
# 352/352 [==============================] - 18s 53ms/step - loss: 0.9169 - accuracy: 0.6853 - val_loss: 0.9996 - val_accuracy: 0.6564
# Epoch 23/25
# 352/352 [==============================] - 19s 54ms/step - loss: 0.9014 - accuracy: 0.6911 - val_loss: 0.9718 - val_accuracy: 0.6696
# Epoch 24/25
# 352/352 [==============================] - 18s 51ms/step - loss: 0.8957 - accuracy: 0.6917 - val_loss: 1.0052 - val_accuracy: 0.6548
# Epoch 25/25
# 352/352 [==============================] - 18s 52ms/step - loss: 0.8902 - accuracy: 0.6945 - val_loss: 0.9901 - val_accuracy: 0.6556

# %%
# Show training history (this cell is complete, nothing to implement here :-) )
h = history.history
epochs = range(len(h['loss']))

plt.subplot(121), plt.plot(epochs, h['loss'], '.-', epochs, h['val_loss'], '.-')
plt.grid(True), plt.xlabel('epochs'), plt.ylabel('loss')
plt.legend(['Train', 'Validation'])
plt.subplot(122), plt.plot(epochs, h['accuracy'], '.-',
                           epochs, h['val_accuracy'], '.-')
plt.grid(True), plt.xlabel('epochs'), plt.ylabel('Accuracy')
plt.legend(['Train', 'Validation'])

print('Train Acc     ', h['accuracy'][-1])
print('Validation Acc', h['val_accuracy'][-1])
# Out:
# Train Acc      0.6944666504859924
# Validation Acc 0.6556000113487244

# %% [markdown]
# ### Step 4: Evaluation
#
# In this step, you have to calculate the accuracies and visualize some random samples. For the evaluation, you are going to use the test split from the dataset.

# %%
# Compute the labels and the predictions as sparse values
y_true = np.argmax(y_test, axis=1)
y_pred = model.predict(x_test)

print('True', y_true[0:5])
print('Pred', np.argmax(y_pred[0:5, :], axis=1))
print('Pred', y_pred[0:5, :])
print(y_pred.shape)
# Out:
# True [3 8 8 0 6]
# Pred [3 1 1 0 4]
# Pred [[1.40254130e-03 1.06377374e-04 2.13632267e-02 9.22037721e-01
#   1.44937483e-03 2.84018368e-02 1.01265833e-02 6.67119049e-04
#   1.34774297e-02 9.67786240e-04]
#  [4.63934913e-02 6.04947567e-01 5.85309463e-05 2.46803597e-06
#   4.97050132e-06 4.77668500e-08 9.27824928e-08 5.80613550e-06
#   2.97329456e-01 5.12575731e-02]
#  [1.85285941e-01 3.52268547e-01 2.86262017e-03 3.80629837e-03
#   5.44536207e-03 5.84201480e-04 9.06845598e-05 3.49582173e-02
#   3.51796418e-01 6.29016981e-02]
#  [6.54935956e-01 2.59991009e-02 3.97463422e-03 2.19805050e-04
#   5.67556778e-03 1.36530361e-05 1.29139837e-04 1.82433880e-03
#   3.04616868e-01 2.61106365e-03]
#  [4.41190205e-05 3.45120323e-04 6.96240738e-02 1.10561378e-01
#   4.63997811e-01 2.62970328e-02 3.28600079e-01 1.68040919e-04
#   1.64048106e-04 1.98373891e-04]]
# (10000, 10)

# %%
# Compute and print the accuracy for each class
for class_id, class_name in classes.items():
    #print(class_id)
    acc = np.sum((np.argmax(y_pred, axis=1)==np.argmax(y_test, axis=1)) & (np.argmax(y_test, axis=1)==class_id))/np.sum(np.argmax(y_test, axis=1)==class_id)
    print(class_name, acc)
# Out:
# plane 0.7
# car 0.782
# bird 0.644
# cat 0.466
# deer 0.472
# dog 0.54
# frog 0.682
# horse 0.758
# ship 0.703
# truck 0.742

# %%
# Print the overall stats
ev = model.evaluate(x_test, y_test)
print('Test loss  ', ev[0])
print('Test metric', ev[1])
# Out:
# 313/313 [==============================] - 3s 9ms/step - loss: 1.0055 - accuracy: 0.6489
# Test loss   1.0054641962051392
# Test metric 0.6488999724388123

# %%
# Show random samples
for ii in range(15):
    # Pick a random sample
    idx = np.random.randint(0, len(y_test))
    # Show the results
    plt.subplot(3,5,ii+1), plt.imshow(x_test[idx, ...])
    plt.title('True: ' + str(classes[y_true[idx]]) + ' | Pred: ' + str(classes[np.argmax(y_pred, axis=1)[idx]]))

# %% [markdown]
# ### Questions
# * What is the overall accuracy of the classifier?
# * What modifications would you do in order to improve the classification accuracy?
# * Make **one** modification (that you think can help) and train the classifier again. Does the accuracy improve?

# %% [markdown]
# ### Answers
#
# 0. The dataset cifar10 is balanced very well
#
# 1. The overall accuracy of the classifier is low about 60%
#
# 2. If look on the training graph, probably is need to increase training epochs. From 25 to 50 or more.
#
# 3. Please see another my Notebook (Homework_50epochs.ipynb) where I only incrased the number of epochs to 50. The result is more better! Unfortunately I do not have CUDA device and I do not have time to make a more experimental with this CNN, to the dedline of this home work  I have 10 mins :)
